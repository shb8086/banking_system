# %% [markdown]
# <a href="https://colab.research.google.com/github/shb8086/ATM/blob/main/diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
data=pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/diabetes.csv")
Y=data.Outcome
#print(Y)
data=data.dropna(axis=0)
#print(data)
#X=data.columns
#print(X)
features=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age']
X=data[features]
print(X)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=1)
from sklearn.model_selection import train_test_split
train_x, val_x, train_y, val_y = train_test_split(X,Y, random_state=0)
model.fit(train_x,train_y)
p=model.predict(val_x)
#print(p)
print(mean_absolute_error(val_y, p))
# Out:
# 0.2708333333333333
